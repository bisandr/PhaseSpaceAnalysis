# %%
# %run stats_elements.py
# Out:
# Element         N       Mean       Mode   KDE peak         SD
# ------------------------------------------------------------
# 1st           431      8.253      1.000      3.194      6.333
# 2nd           431     16.346     11.000     13.426      8.149
# 3rd           431     25.044     30.000     23.362      8.799
# 4th           431     33.473     37.000     35.031      8.517
# 5th           431     42.095     50.000     47.155      6.874
#
# Results saved to data/element_stats.csv
