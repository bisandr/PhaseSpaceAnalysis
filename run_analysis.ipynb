# %%
# %run phase_space_analysis.py data/diff_2nd-1st.csv
# Out:
# Phase Space Analysis Summary
# --------------------------------
# Optimal time delay (τ): 7
# Optimal embedding dimension (m): 4
# Largest Lyapunov Exponent (LLE): -0.018104
# RQA Metrics:
#   RR: 1.865556
#   DET: 2.201027
#   Lmax: 2.000000
#   Lmean: 2.000000
#   ENT: -0.000000
#   LAM: 6.052825
#   TT: 2.012195
