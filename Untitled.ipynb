# %%
# %run extract_series.py
# Out:
# Files written:
#   data/element_1st.csv
#   data/element_2nd.csv
#   data/element_3rd.csv
#   data/element_4th.csv
#   data/element_5th.csv
#   data/diff_2nd-1st.csv
#   data/diff_3rd-2nd.csv
#   data/diff_4th-3rd.csv
#   data/diff_5th-4th.csv
#   data/diff_sums.csv
